# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import scipy.integrate

# %%
df = pd.read_csv("/media/sf_Ubuntu/share/stock4newtunesummer.csv")
df
# Out:
#           t_start_Buf       m468
# 0    26/06/2017 03:37   0.945139
# 1    26/06/2017 03:37   1.193680
# 2    26/06/2017 03:37   1.477220
# 3    26/06/2017 03:37   1.645240
# 4    26/06/2017 03:37   0.742109
# 5    26/06/2017 03:37   4.606680
# 6    26/06/2017 03:37   0.000000
# 7    26/06/2017 03:37   3.686040
# 8    26/06/2017 03:37   0.857627
# 9    26/06/2017 03:37   0.717606
# 10   26/06/2017 03:37   2.653390
# 11   26/06/2017 03:37   0.000000
# 12   26/06/2017 03:37   1.729250
# 13   26/06/2017 03:37   2.464360
# 14   26/06/2017 03:37   1.799270
# 15   26/06/2017 03:37   0.000000
# 16   26/06/2017 03:37   1.043150
# 17   26/06/2017 03:37   0.000000
# 18   26/06/2017 03:37   3.094460
# 19   26/06/2017 03:37   4.281130
# 20   26/06/2017 03:37   3.328990
# 21   26/06/2017 03:37   0.574085
# 22   26/06/2017 03:37   5.964880
# 23   26/06/2017 03:37   1.960290
# 24   26/06/2017 03:37   0.150522
# 25   26/06/2017 03:37   2.054800
# 26   26/06/2017 03:37   4.862220
# ...

# %%
scipy.integrate.cumtrapz(df['m468'],x=None, dx=650.0)
y_int = scipy.integrate.cumptrapz('m468','utc',initial=0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-7aa1d4333158> in <module>()
#       1 scipy.integrate.cumtrapz(df['m468'],x=None, dx=650.0)
# ----> 2 y_int = scipy.integrate.cumptrapz('m468','utc',initial=0)
#
# AttributeError: module 'scipy.integrate' has no attribute 'cumptrapz'

# %%
integral = np.trapz(df['m468'],x=None,dx=1.0, axis = -1)
integral
# Out:
# 18679.1165415

# %%
mix1 =
