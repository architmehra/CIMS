# %% [markdown]
# # Import data from .csv and time correct

# %%
import pandas as pd
import numpy as np
import engarde.checks as ck
import engarde.decorators as dc
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/media/sf_Ubuntu/share/ultimatecimsdataset.csv")

# %%
df = df.fillna('') #replace nans with blank string as causing problems 
df.IMRPRESSURE.plot()
plt.show()

# %%
df['UTC'] = pd.to_datetime(df['UTC'])

# %%
df = df[((df.IMRPRESSURE - df.IMRPRESSURE.mean())/ df.IMRPRESSURE.std()).abs()<1.5]
df.IMRPRESSURE.plot()
plt.show()

# %%
dc.test_within_n_std()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-fa0b3dae9b76> in <module>()
# ----> 1 dc.test_within_n_std()
#
# AttributeError: module 'engarde.decorators' has no attribute 'test_within_n_std'

# %%
engarde.checks.is_monotonic(df)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-259-dee872f5175c> in <module>()
# ----> 1 engarde.checks.is_monotonic(df)
#
# /home/archit/anaconda3/lib/python3.6/site-packages/engarde/checks.py in is_monotonic(df, items, increasing, strict)
#      80                 good = good & (s.to_series().diff().dropna() < 0).all()
#      81         if not good:
# ---> 82             raise AssertionError
#      83     return df
#      84
#
# AssertionError:

# %%
engarde.checks.unique(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-261-6a8ee4483585> in <module>()
# ----> 1 engarde.checks.unique(df)
#
# AttributeError: module 'engarde.checks' has no attribute 'unique'

# %%
#start().dtypes

# %%
##THIS CAN BE USED TO FILTER THE DATA ON MULTIPLE PARAMETERS

start()
def pressurechange():
    r = ((df.IMRPRESSURE <1000)) & ((df.SSQPRESSURE > 2))
    return r

# %%
def remove_pressure_changes(cims_df):
    r = cims_df.query((df.IMRPRESSURE <900.00)) #add something about SSQ pressure here 
    return r

# %%
pressure_corrected_df = start().pipe(remove_pressure_changes)
pressure_corrected_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-172-f64e8de2076e> in <module>()
# ----> 1 pressure_corrected_df = start().pipe(remove_pressure_changes)
#       2 pressure_corrected_df.head()
#
# /home/archit/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in pipe(self, func, *args, **kwargs)
#    2706             return func(*args, **kwargs)
#    2707         else:
# -> 2708             return func(self, *args, **kwargs)
#    2709
#    2710     # ----------------------------------------------------------------------
#
# <ipython-input-171-cfe23d043dc6> in remove_pressure_changes(cims_df)
#       1 def remove_pressure_changes(cims_df):
# ----> 2     r = cims_df.query((df.IMRPRESSURE <900.00)) #add something about SSQ pressure here
#       3     return r
#
# ...

# %%
cleaned_df = start().pipe(remove_pressure_changes)

#cleaned gas and particle phase dataset
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-173-bfef0744988b> in <module>()
# ----> 1 cleaned_df = start().pipe(remove_pressure_changes)
#       2
#       3 #cleaned gas and particle phase dataset
#
# /home/archit/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in pipe(self, func, *args, **kwargs)
#    2706             return func(*args, **kwargs)
#    2707         else:
# -> 2708             return func(self, *args, **kwargs)
#    2709
#    2710     # ----------------------------------------------------------------------
#
# <ipython-input-171-cfe23d043dc6> in remove_pressure_changes(cims_df)
#       1 def remove_pressure_changes(cims_df):
# ----> 2     r = cims_df.query((df.IMRPRESSURE <900.00)) #add something about SSQ pressure here
#       3     return r
#
# ...

# %%
cleaned_gas_df = cleaned_df().pipe(gas phase only)
cleaned_aerosol_df = cleaned_df().pipe(aerosol phase only)
# Out:
#   File "<ipython-input-174-87292e322c8f>", line 1
#     cleaned_gas_df = cleaned_df().pipe(gas phase only)
#                                                ^
# SyntaxError: invalid syntax

# %%
engarde.checks.within_n_std(start()['IMRPRESSURE'],n=3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-176-b45bd2974b17> in <module>()
# ----> 1 engarde.checks.within_n_std(start()['IMRPRESSURE'],n=3)
#
# /home/archit/anaconda3/lib/python3.6/site-packages/engarde/checks.py in within_n_std(df, n)
#     191     inliers = (np.abs(df - means) < n * stds)
#     192     if not np.all(inliers):
# --> 193         msg = generic.bad_locations(~inliers)
#     194         raise AssertionError(msg)
#     195     return df
#
# /home/archit/anaconda3/lib/python3.6/site-packages/engarde/generic.py in bad_locations(df)
#      71
#      72 def bad_locations(df):
# ---> 73     columns = df.columns
#      74     all_locs = chain.from_iterable(zip(df.index, cycle([col])) for col in columns)
#      75     bad = pd.Series(list(all_locs))[np.asarray(df).ravel(1)]
#
# ...
